# %% [markdown]
# <a href="https://colab.research.google.com/github/irwanmazlin/OCR/blob/0.2.0/Tesseract_OCR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 19 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !ls
# Out:
# sample1.png  sample_data

# %%
import pytesseract
import shutil
import os
import random
import cv2
import matplotlib.pyplot as plt
# from google.colab.patches import cv2_imshow

# %% [markdown]
# ## Open Image:

# %%
img = cv2.imread('sample1.png')
plt.imshow(img)

# %% [markdown]
# ### top

# %%
crop_imgtoppart1 = img[60:90,  270:340]
# img[110:140,  270:345]
# plt.imshow(crop_imgtoppart1)

resizetoppart1 = cv2.resize(crop_imgtoppart1, (275, 300), interpolation = cv2.INTER_AREA)

rgbImagetoppart1 = cv2.cvtColor(resizetoppart1, cv2.COLOR_BGR2RGB)
grayImagetoppart1 = cv2.cvtColor(rgbImagetoppart1, cv2.COLOR_BGR2GRAY)
erd = cv2.erode(grayImagetoppart1, None, iterations=0)

plt.imshow(erd, cmap="gray")
extractedInformation1 = pytesseract.image_to_string(erd)
string1 = extractedInformation1.split()
print(string1)
# Out:
# ['Product:']

# %%
crop_imgtoppart2 = img[70:85, 347:390]
plt.imshow(crop_imgtoppart2)

# resizetoppart1 = cv2.resize(crop_imgtoppart1, (460, 150), interpolation = cv2.INTER_AREA)

rgbImagetoppart2 = cv2.cvtColor(crop_imgtoppart2, cv2.COLOR_BGR2RGB)
grayImagetoppart2 = cv2.cvtColor(rgbImagetoppart2, cv2.COLOR_BGR2GRAY)
# erd = cv2.erode(grayImagetoppart1, None, iterations=0)

plt.imshow(grayImagetoppart2, cmap="gray")
extractedInformation2 = pytesseract.image_to_string(grayImagetoppart2)
string2 = extractedInformation2.split()
print(string2)
# Out:
# ['02.']

# %%
crop_imgtoppart3 = img[60:90,  445:700]
# img[110:140,  270:345]
# plt.imshow(crop_imgtoppart1)

# resizetoppart3 = cv2.resize(crop_imgtoppart1, (275, 300), interpolation = cv2.INTER_AREA)

rgbImagetoppart3 = cv2.cvtColor(crop_imgtoppart3, cv2.COLOR_BGR2RGB)
grayImagetoppart3 = cv2.cvtColor(rgbImagetoppart3, cv2.COLOR_BGR2GRAY)
erd = cv2.erode(grayImagetoppart3, None, iterations=0)

plt.imshow(erd, cmap="gray")
extractedInformation3 = pytesseract.image_to_string(erd)
string3 = extractedInformation3.split()
print(string3)

finalstring1 = ' '.join(string1 + string2 + string3)
print(finalstring1)
# Out:
# ['SOYA', 'MEAL']
# Product: 02. SOYA MEAL

# %%
crop_imgtoppart4 = img[110:140,  270:345]
# plt.imshow(crop_imgtoppart2)

# resizetoppart1 = cv2.resize(crop_imgtoppart1, (460, 150), interpolation = cv2.INTER_AREA)

rgbImagetoppart4 = cv2.cvtColor(crop_imgtoppart4, cv2.COLOR_BGR2RGB)
grayImagetoppart4 = cv2.cvtColor(rgbImagetoppart4, cv2.COLOR_BGR2GRAY)

plt.imshow(grayImagetoppart4, cmap="gray")
extractedInformation4 = pytesseract.image_to_string(grayImagetoppart4)
string4 = extractedInformation4.split()
print(string4)
# Out:
# ['From:']

# %%
crop_imgtoppart5 = img[110:140,  347:420]
# plt.imshow(crop_imgtoppart2)

# resizetoppart1 = cv2.resize(crop_imgtoppart1, (460, 150), interpolation = cv2.INTER_AREA)

rgbImagetoppart5 = cv2.cvtColor(crop_imgtoppart5, cv2.COLOR_BGR2RGB)
grayImagetoppart5 = cv2.cvtColor(rgbImagetoppart5, cv2.COLOR_BGR2GRAY)

plt.imshow(grayImagetoppart5, cmap="gray")
extractedInformation5 = pytesseract.image_to_string(grayImagetoppart5)
string5 = extractedInformation5.split()
print(string5)
# Out:
# ['Vessel']

# %%
crop_imgtoppart6 = img[113:135,  468:530]
# plt.imshow(crop_imgtoppart2)

# resizetoppart1 = cv2.resize(crop_imgtoppart1, (460, 150), interpolation = cv2.INTER_AREA)

rgbImagetoppart6 = cv2.cvtColor(crop_imgtoppart6, cv2.COLOR_BGR2RGB)
grayImagetoppart6 = cv2.cvtColor(rgbImagetoppart6, cv2.COLOR_BGR2GRAY)

plt.imshow(grayImagetoppart6, cmap="gray")
extractedInformation6 = pytesseract.image_to_string(grayImagetoppart6)
string6 = extractedInformation6.split()
print(string6)
# Out:
# ['227BXY']

# %%
crop_imgtoppart7 = img[113:135,  565:700]
# plt.imshow(crop_imgtoppart2)

# resizetoppart1 = cv2.resize(crop_imgtoppart1, (460, 150), interpolation = cv2.INTER_AREA)

rgbImagetoppart7 = cv2.cvtColor(crop_imgtoppart7, cv2.COLOR_BGR2RGB)
grayImagetoppart7 = cv2.cvtColor(rgbImagetoppart7, cv2.COLOR_BGR2GRAY)

plt.imshow(grayImagetoppart7, cmap="gray")
extractedInformation7 = pytesseract.image_to_string(grayImagetoppart7)
string7 = extractedInformation7.split()
print(string7)

finalstring2 = ' '.join(string4 + string5 + string6 + string7)
print(finalstring2)
# Out:
# ['MY.', 'SOYA', 'TIANJIN,']
# From: Vessel 227BXY MY. SOYA TIANJIN,

# %%
crop_imgtoppart8 = img[140:180, 270:345]



# crop_imgtoppart3 = img[140:180, 270:700]
# plt.imshow(crop_imgtoppart3)

# resizetoppart3 = cv2.resize(crop_imgtoppart3, (500, 40), interpolation = cv2.INTER_AREA)

rgbImagetoppart8 = cv2.cvtColor(crop_imgtoppart8, cv2.COLOR_BGR2RGB)
grayImagetoppart8 = cv2.cvtColor(rgbImagetoppart8, cv2.COLOR_BGR2GRAY)

plt.imshow(grayImagetoppart8, cmap="gray")
extractedInformation8 = pytesseract.image_to_string(grayImagetoppart8)
string8 = extractedInformation8.split()
print(string8)
# Out:
# ['To:']

# %%
crop_imgtoppart9 = img[155:175, 349:423]


# crop_imgtoppart3 = img[140:180, 270:700]
# plt.imshow(crop_imgtoppart3)

# resizetoppart3 = cv2.resize(crop_imgtoppart3, (500, 40), interpolation = cv2.INTER_AREA)

rgbImagetoppart9 = cv2.cvtColor(crop_imgtoppart9, cv2.COLOR_BGR2RGB)
grayImagetoppart9 = cv2.cvtColor(rgbImagetoppart9, cv2.COLOR_BGR2GRAY)

plt.imshow(grayImagetoppart9, cmap="gray")
extractedInformation9 = pytesseract.image_to_string(grayImagetoppart9)
string9 = extractedInformation9.split()
print(string9)
# Out:
# ['Customer']

# %%
crop_imgtoppart10 = img[155:175, 469:530]


# crop_imgtoppart3 = img[140:180, 270:700]
# plt.imshow(crop_imgtoppart3)

# resizetoppart10 = cv2.resize(crop_imgtoppart3, (45, 5), interpolation = cv2.INTER_AREA)

rgbImagetoppart10 = cv2.cvtColor(crop_imgtoppart10, cv2.COLOR_BGR2RGB)
grayImagetoppart10 = cv2.cvtColor(rgbImagetoppart10, cv2.COLOR_BGR2GRAY)

plt.imshow(grayImagetoppart10, cmap="gray")
extractedInformation10 = pytesseract.image_to_string(grayImagetoppart10)
string10 = extractedInformation10.split()
print(string10)
# Out:
# ['03']

# %%
crop_imgtoppart11 = img[155:175, 565:700]


# crop_imgtoppart3 = img[140:180, 270:700]
# plt.imshow(crop_imgtoppart3)

# resizetoppart10 = cv2.resize(crop_imgtoppart3, (45, 5), interpolation = cv2.INTER_AREA)

rgbImagetoppart11 = cv2.cvtColor(crop_imgtoppart11, cv2.COLOR_BGR2RGB)
grayImagetoppart11 = cv2.cvtColor(rgbImagetoppart11, cv2.COLOR_BGR2GRAY)

plt.imshow(grayImagetoppart11, cmap="gray")
extractedInformation11 = pytesseract.image_to_string(grayImagetoppart11)
string11 = extractedInformation11.split()
finalstring3 = ' '.join(string8 + string9 + string10 + string11)

print(finalstring1)
print(finalstring2)
print(finalstring3)
# Out:
# Product: 02. SOYA MEAL
# From: Vessel 227BXY MY. SOYA TIANJIN,
# To: Customer 03 INDAH GRAIN B

# %% [markdown]
# ### info mid

# %%
crop_img1 = img[230: 470, 280:770]
plt.imshow(crop_img1)

# %%
crop_img1 = img[230: 470, 280:770]
# plt.imshow(crop_img1)
resize = cv2.resize(crop_img1, (900, 500), interpolation = cv2.INTER_AREA)
grayImage12 = cv2.cvtColor(resize, cv2.COLOR_BGR2GRAY)
plt.imshow(grayImage12, cmap="gray")

# extractedInformation12 = pytesseract.image_to_string(grayImage12)
# string12 = extractedInformation12.split()
# finalstring4 = ' '.join(string12)

text = str(((pytesseract.image_to_string(grayImage12))))
# text = text.replace('\n', ' ')
print("text : ", text)
# plt.imshow(resize)
# Out:
# text :
#
#
#
# Tip# Time Gross (Kg) Tare (Kg) Net (Kg)
# 83 08:44:16 2498.0 0.0 2498.0
# 82 08:43:59 2490.0 0.0 2490.0
# 81 08:43:41 2172.0 0.0 2172.0
# 80 08:42:41 2598.0 0.0 2598.0
# 19 08:42:25 2094.0 0.0 2094.0

# %%
crop_img13 = crop_img1[25: 50, 0:900]
# plt.imshow(crop_img1)
resize13 = cv2.resize(crop_img13, (1280, 80), interpolation = cv2.INTER_AREA)
grayImage13 = cv2.cvtColor(resize13, cv2.COLOR_BGR2GRAY)
plt.imshow(grayImage13, cmap="gray")

# extractedInformation12 = pytesseract.image_to_string(grayImage12)
# string12 = extractedInformation12.split()
# finalstring4 = ' '.join(string12)

text = str(((pytesseract.image_to_string(grayImage13))))
# text = text.replace('\n', ' ')
print("text : ", text)
# plt.imshow(resize)
# Out:
# text :  83 08:44:16 2498.0 0.0 2498.0

# %%
crop_img14 = crop_img1[60: 90, 0:900]
# plt.imshow(crop_img1)
resize14 = cv2.resize(crop_img14, (1280, 80), interpolation = cv2.INTER_AREA)
grayImage14 = cv2.cvtColor(resize14, cv2.COLOR_BGR2GRAY)
plt.imshow(grayImage14, cmap="gray")

# extractedInformation12 = pytesseract.image_to_string(grayImage12)
# string12 = extractedInformation12.split()
# finalstring4 = ' '.join(string12)

text = str(((pytesseract.image_to_string(grayImage14))))
# text = text.replace('\n', ' ')
print("text : ", text)
# plt.imshow(resize)
# Out:
# text :  82 08:43:59 2490.0 0.0 2490.0

# %%
crop_img15 = crop_img1[100: 120, 0:900]
# plt.imshow(crop_img1)
resize15 = cv2.resize(crop_img15, (1280, 80), interpolation = cv2.INTER_AREA)
grayImage15 = cv2.cvtColor(resize15, cv2.COLOR_BGR2GRAY)
plt.imshow(grayImage15, cmap="gray")

# extractedInformation12 = pytesseract.image_to_string(grayImage12)
# string12 = extractedInformation12.split()
# finalstring4 = ' '.join(string12)

text = str(((pytesseract.image_to_string(grayImage15))))
# text = text.replace('\n', ' ')
print("text : ", text)
# plt.imshow(resize)
# Out:
# text :  81 08:43:41 2172.0 0.0 2172.0

# %%
crop_img16 = crop_img1[135: 155, 0:900]
# plt.imshow(crop_img1)
resize16 = cv2.resize(crop_img16, (1280, 80), interpolation = cv2.INTER_AREA)
grayImage16 = cv2.cvtColor(resize16, cv2.COLOR_BGR2GRAY)
plt.imshow(grayImage16, cmap="gray")

# extractedInformation12 = pytesseract.image_to_string(grayImage12)
# string12 = extractedInformation12.split()
# finalstring4 = ' '.join(string12)

text = str(((pytesseract.image_to_string(grayImage16))))
# text = text.replace('\n', ' ')
print("text : ", text)
# plt.imshow(resize)
# Out:
# text :  80 08:42:41 2598.0 0.0 2598.0

# %%
crop_img17 = crop_img1[170: 190, 0:900]
plt.imshow(crop_img17)
resize17 = cv2.resize(crop_img17, (1280, 80), interpolation = cv2.INTER_AREA)
grayImage17 = cv2.cvtColor(resize17, cv2.COLOR_BGR2GRAY)
plt.imshow(grayImage17, cmap="gray")

# extractedInformation12 = pytesseract.image_to_string(grayImage12)
# string12 = extractedInformation12.split()
# finalstring4 = ' '.join(string12)

text = str(((pytesseract.image_to_string(grayImage17))))
# text = text.replace('\n', ' ')
print("text : ", text)
# plt.imshow(resize)
# Out:
# text :  79 08:42:25 2094.0 0.0 2094.0

# %% [markdown]
# ### **info bottom**

# %%
crop_img3 = img[475: 515, 275:790]
plt.imshow(crop_img3)

# %%
resize33 = cv2.resize(crop_img3, (480, 40), interpolation = cv2.INTER_AREA)
grayImage33 = cv2.cvtColor(resize33, cv2.COLOR_BGR2GRAY)
plt.imshow(grayImage33, cmap="gray")

extractedInformation33 = pytesseract.image_to_string(grayImage33)
print(extractedInformation33)
# plt.imshow(resize)
# Out:
# Filling Rate: 546 Th Total Tips: 83 Total In Scale: 191,620 Kg

# %% [markdown]
# ### Testing

# %%
# invertImg = cv2.bitwise_not(grayImage)
# plt.imshow(invertImg)
# extractedInformation2 = pytesseract.image_to_string(invertImg)
# print(extractedInformation2)

# %%
(thresh, blackwhite) = cv2.threshold(invertImg, 80, 255, cv2.THRESH_BINARY)
plt.imshow(blackwhite)
extractedInformation3 = pytesseract.image_to_string(invertImg)
print(extractedInformation3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-f9f68128164d> in <module>()
# ----> 1 (thresh, blackwhite) = cv2.threshold(invertImg, 80, 255, cv2.THRESH_BINARY)
#       2 plt.imshow(blackwhite)
#       3 extractedInformation3 = pytesseract.image_to_string(invertImg)
#       4 print(extractedInformation3)
#
# NameError: name 'invertImg' is not defined
